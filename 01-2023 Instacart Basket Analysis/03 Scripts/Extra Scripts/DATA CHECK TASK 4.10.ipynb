# %% [markdown]
# ## DATA CHECK TASK 4.10

# %% [markdown]
# ### -Re-checking data and re-checking some results due to main large notebook crashing and new notebook will save time and prevent computer problems

# %%
# Importing libraries to computer
import pandas as pd
import numpy as np
import os

# %%
# Creating a data importing shortcut called 'path' for the Instacart folder to make importing data easier and cleaner
path =r'/Users/drewsmith/Desktop/01-2023 Instacart Basket Analysis'

# %%
# Utilizing the created 'path' shortcut to import the 'Products' dataset 
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
# Utilizing the created 'path' shortcut to import the 'Products' dataset 
prods_check = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
prods_check.shape
# Out:
# (49672, 6)

# %%
# Utilizing the created 'path' shortcut to import the 'new_ords_prods_merge' dataset 
ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'cus_ords_prods.pkl'))

# %%
ords_prods.shape
# Out:
# (32404859, 34)

# %%
# Utilizing the created 'path' shortcut to import the 'new_ords_prods_merge' dataset 
ords_merg = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_merg.shape
# Out:
# (32404859, 15)

# %%
# Utilizing the created 'path' shortcut to import the 'new_ords_prods_merge' dataset 
ords_upd = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'updated_orders_products_merged.pkl'))

# %%
ords_upd.shape
# Out:
# (32404859, 19)

# %%
# Utilizing the created 'path' shortcut to import the 'new_ords_prods_merge' dataset 
ords_new = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'new_ords_prods_merge.pkl'))

# %%
ords_new.shape
# Out:
# (32404859, 25)

# %%
# Utilizing the created 'path' shortcut to import the 'new_ords_prods_merge' dataset 
final1 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final_insta_data.pkl'))

# %%
final1.head(50)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2539329        1             1                   2                  8
# ...

# %%
# Doesn't assign any options to the max number of columns so the 'head()' function can display all columns
pd.options.display.max_columns = None

# %%
final1.shape
# Out:
# (32404859, 35)

# %%
# Utilizing the created 'path' shortcut to import the 'Products' dataset 
cus = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %%
cus.shape
# Out:
# (206209, 10)

# %%
# Displays only rows that are duplicates in df_ords1 dataframe under a new subset
cus_dups = cus[cus.duplicated()]

# %%
cus_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surnam, Gender, STATE, Age, date_joined, n_dependants, fam_status, income]
# Index: []

# %%
# Used to find missing observations or entries in the products dataframe
cus.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# Utilizing the created 'path' shortcut to import the 'new_ords_prods_merge' dataset 
dff = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
# Displays only rows that are duplicates in df_ords1 dataframe under a new subset
ords_dups = dff[dff.duplicated()]

# %%
ords_dups
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# Used to find missing observations or entries in the products dataframe
dff.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
dff.shape
# Out:
# (32434489, 4)
